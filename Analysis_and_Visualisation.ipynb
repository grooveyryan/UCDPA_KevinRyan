# %%
import pandas as pd # Importing Pandas and calling it pd

import numpy as np # Importing Numpy and calling it np

import seaborn as sns # Importing Seaborn and calling it sns

import matplotlib.pyplot as plt

pga = pd.read_csv(r'/Users/kevryan/desktop/PGATOUR_data2.csv') # Importing data set and assigning it variable name 'pga'

pd.DataFrame(pga) # Printing the dataset
# Out:
#              Player  EVENTS_PLAYED  POINTS  NUMBER_OF_WINS  \
# 0    Aaron Baddeley           27.0   342.0             0.0
# 1        Aaron Wise           27.0  1498.0             1.0
# 2     Abraham Ancer           29.0   909.0             0.0
# 3       Adam Hadwin           24.0  1054.0             0.0
# 4       Adam Schenk           28.0   239.0             0.0
# ..              ...            ...     ...             ...
# 326             NaN            NaN     NaN             NaN
# 327             NaN            NaN     NaN             NaN
# 328             NaN            NaN     NaN             NaN
# 329             NaN            NaN     NaN             NaN
# 330             NaN            NaN     NaN             NaN
#
#      NUMBER_OF_TOP_Tens  POINTS_BEHIND_LEAD  ROUNDS_PLAYED  \
# 0                   1.0              5275.0           84.0
# 1                   4.0              4119.0           82.0
# 2                   5.0              4708.0           94.0
# ...

# %%
pga = pga.dropna() # Dropping missing data
display(pga)
# Out:
#                 Player  EVENTS_PLAYED  POINTS  NUMBER_OF_WINS  \
# 0       Aaron Baddeley           27.0   342.0             0.0
# 1           Aaron Wise           27.0  1498.0             1.0
# 2        Abraham Ancer           29.0   909.0             0.0
# 3          Adam Hadwin           24.0  1054.0             0.0
# 4          Adam Schenk           28.0   239.0             0.0
# ..                 ...            ...     ...             ...
# 190  Xander Schauffele           25.0  1109.0             0.0
# 191       Xinjun Zhang           28.0   195.0             0.0
# 192          Zac Blair           20.0   176.0             0.0
# 193       Zach Johnson           24.0   890.0             0.0
# 194        Zecheng Dou           23.0    21.0             0.0
#
#      NUMBER_OF_TOP_Tens  POINTS_BEHIND_LEAD  ROUNDS_PLAYED  \
# 0                   1.0              5275.0           84.0
# 1                   4.0              4119.0           82.0
# ...

# %%
list(pga) # Listing all fields in pga
# Out:
# ['Player',
#  'EVENTS_PLAYED',
#  'POINTS',
#  'NUMBER_OF_WINS',
#  'NUMBER_OF_TOP_Tens',
#  'POINTS_BEHIND_LEAD',
#  'ROUNDS_PLAYED',
#  'SG_PUTTING_PER_ROUND',
#  'TOTAL_SG:PUTTING',
#  'MEASURED_ROUNDS',
#  'AVG_Driving_DISTANCE',
#  'UP_AND_DOWN_%',
#  'PAR_OR_BETTER',
#  'MISSED_GIR',
#  'FAIRWAY_HIT_%',
#  'FAIRWAYS_HIT',
#  'POSSIBLE_FAIRWAYS',
#  'GIR_RANK',
#  'GOING_FOR_GREEN_IN_2%',
#  'ATTEMPTS_GFG',
#  'NON-ATTEMPTS_GFG',
#  'RTP-GOING_FOR_THE_GREEN',
#  'RTP-NOT_GOING_FOR_THE_GRN',
#  'HOLE_OUTS',
#  'SAND_SAVE%',
#  'NUMBER_OF_SAVES',
#  'NUMBER_OF_BUNKERS',
#  'TOTAL_O/U_PAR',
#  'Three_PUTT%',
#  'TOTAL_3_PUTTS',
#  'SG_PER_ROUND',
#  'SG:OTT',
#  'SG:APR',
#  'SG:ARG',
#  'DRIVES_320+%',
#  'TOTAL_DRIVES_FOR_320+',
#  'TOTAL_DRIVES',
#  'ROUGH_TENDNECY%',
#  'TOTAL_ROUGH',
#  'FAIRWAY_BUNKER%',
#  'TOTAL_FAIRWAY_BUNKERS',
#  'AVG_CLUB_HEAD_SPEED',
#  'FASTEST_CH_SPEED',
#  'SLOWEST_CH_SPEED',
#  'AVG_BALL_SPEED',
#  'FASTEST_BALL_SPEED',
#  'SLOWEST_BALL_SPEED',
# ...

# %%
pga_avg_spin = pga.sort_values("AVG_SPIN_RATE", ascending = False) # Creating pga__avg_spin DataFrame with golfers with highest AVG_SPIN_RATE on top

print(pga.columns.get_loc("AVG_SPIN_RATE")) # Getting index of AVG_SPIN_RATE column
# Out:
# 53

# %%
display(pga_avg_spin) # Display pga_avg_spin DataFrame
# Out:
#               Player  EVENTS_PLAYED  POINTS  NUMBER_OF_WINS  \
# 49   Conrad Shindler           20.0    92.0             0.0
# 174    Ted Potter Jr           27.0   809.0             1.0
# 7         Alex Noren           17.0  1033.0             0.0
# 130        Pat Perez           22.0  1167.0             1.0
# 132     Patrick Reed           24.0  1761.0             1.0
# ..               ...            ...     ...             ...
# 37     Cameron Percy           16.0   191.0             0.0
# 68     Greg Chalmers           20.0   133.0             0.0
# 89          John Huh           29.0   480.0             0.0
# 82         Jason Day           18.0  1935.0             2.0
# 48      Cody Gribble           25.0   141.0             0.0
#
#      NUMBER_OF_TOP_Tens  POINTS_BEHIND_LEAD  ROUNDS_PLAYED  \
# 49                  0.0              5525.0           60.0
# 174                 1.0              4808.0           83.0
# 7                   3.0              4584.0           63.0
# ...

# %%
pga_avg_spin[['Player', 'AVG_SPIN_RATE']] # Show Player and AVG_SPIN_RATE for pga_avg_spin DataFrame
# Out:
#               Player  AVG_SPIN_RATE
# 49   Conrad Shindler         3346.1
# 174    Ted Potter Jr         3152.8
# 7         Alex Noren         3143.2
# 130        Pat Perez         3127.4
# 132     Patrick Reed         3048.3
# ..               ...            ...
# 37     Cameron Percy         2216.1
# 68     Greg Chalmers         2213.0
# 89          John Huh         2197.1
# 82         Jason Day         2131.0
# 48      Cody Gribble         2127.3
#
# [194 rows x 2 columns]

# %%
pga_avg_spin = pga_avg_spin.drop_duplicates() # Dropping duplicate rows

top_50_avg_spin = pga_avg_spin.head(50) # Creating top_50_avg_spin DataFrame from the top 50 rows in pga_avg_spin
display(top_50_avg_spin) # Displaying top_50_avg_spin DataFrame
# Out:
#                   Player  EVENTS_PLAYED  POINTS  NUMBER_OF_WINS  \
# 49       Conrad Shindler           20.0    92.0             0.0
# 174        Ted Potter Jr           27.0   809.0             1.0
# 7             Alex Noren           17.0  1033.0             0.0
# 130            Pat Perez           22.0  1167.0             1.0
# 132         Patrick Reed           24.0  1761.0             1.0
# 105           Kevin Tway           31.0   643.0             0.0
# 85       Jhonattan Vegas           27.0   598.0             0.0
# 4            Adam Schenk           28.0   239.0             0.0
# 120           Matt Jones           23.0   264.0             0.0
# 163         Seamus Power           28.0   455.0             0.0
# 112            Luke List           28.0  1111.0             0.0
# 157            Sam Ryder           26.0   551.0             0.0
# 137        Peter Uihlein           25.0   843.0             0.0
# 3            Adam Hadwin           24.0  1054.0             0.0
# ...

# %%
bottom_50_avg_spin = pga_avg_spin.tail(50) # Creating bottom_50_avg_spin DataFrame from the bottom 50 rows in pga_avg_spin
display(bottom_50_avg_spin) # Displaying bottom_50_avg_spin DataFrame
# Out:
#                  Player  EVENTS_PLAYED  POINTS  NUMBER_OF_WINS  \
# 27         Brian Harman           24.0  1116.0             0.0
# 172           Sung Kang           29.0   490.0             0.0
# 188            Whee Kim           30.0   805.0             0.0
# 162     Scott Stallings           30.0   608.0             0.0
# 45          Chez Reavie           27.0  1184.0             0.0
# 92          Jonas Blixt           23.0   167.0             0.0
# 139  Rafa Cabrera Bello           19.0  1121.0             0.0
# 124        Nate Lashley           17.0   168.0             0.0
# 168      Smylie Kaufman           22.0    74.0             0.0
# 35        Byeong Hun An           23.0  1061.0             0.0
# 58       Derek Fathauer           28.0   316.0             0.0
# 63         Fabian Gomez           28.0   221.0             0.0
# 155          Ryan Moore           22.0   806.0             0.0
# 78           J.J. Spaun           26.0   880.0             0.0
# ...

# %%
top_50_avg_spin[['Player','AVG_SPIN_RATE']] # Accessing only the Player and AVG_SPIN_RATE columns of the top_50_avg_spin DataFrame
# Out:
#                   Player  AVG_SPIN_RATE
# 49       Conrad Shindler         3346.1
# 174        Ted Potter Jr         3152.8
# 7             Alex Noren         3143.2
# 130            Pat Perez         3127.4
# 132         Patrick Reed         3048.3
# 105           Kevin Tway         3026.3
# 85       Jhonattan Vegas         3013.8
# 4            Adam Schenk         3006.1
# 120           Matt Jones         3004.9
# 163         Seamus Power         2992.9
# 112            Luke List         2963.1
# 157            Sam Ryder         2962.8
# 137        Peter Uihlein         2961.6
# 3            Adam Hadwin         2952.0
# 50         Corey Conners         2942.9
# 56       David Lingmerth         2928.3
# 103             Kevin Na         2909.3
# 55           David Hearn         2906.2
# 5             Adam Scott         2903.8
# 6             Alex Cejka         2899.2
# 107         Kyle Stanley         2891.2
# 43       Charley Hoffman         2888.6
# ...

# %%
bottom_50_avg_spin[['Player','AVG_SPIN_RATE']] # Accessing only the Player and AVG_SPIN_RATE columns of bottom_50_avg_spin DataFrame
# Out:
#                  Player  AVG_SPIN_RATE
# 27         Brian Harman         2509.7
# 172           Sung Kang         2506.9
# 188            Whee Kim         2504.3
# 162     Scott Stallings         2500.5
# 45          Chez Reavie         2500.0
# 92          Jonas Blixt         2496.8
# 139  Rafa Cabrera Bello         2488.3
# 124        Nate Lashley         2484.4
# 168      Smylie Kaufman         2484.2
# 35        Byeong Hun An         2481.9
# 58       Derek Fathauer         2479.8
# 63         Fabian Gomez         2475.7
# 155          Ryan Moore         2472.9
# 78           J.J. Spaun         2467.2
# 66      Graeme McDowell         2458.3
# 159     Satoshi Kodaira         2458.1
# 109       Lanto Griffin         2451.1
# 175         Tiger Woods         2448.7
# 121         Matt Kuchar         2447.8
# 143        Ricky Barnes         2427.3
# 90       Johnson Wagner         2421.0
# 96          Justin Rose         2416.0
# 44       Chesson Hadley         2414.2
# ...

# %%
pga['BOGEYS_MADE'].sum() # Using the sum function from the Numpy package to calculate the total number of bogeys made from the pga DataFrame
# Out:
# 43092.0

# %%
round(pga['AVG_SPIN_RATE'].mean(), 2) # Using the mean function from the Numpy package to calculate the average spin rate from the pga DataFrame. Rounding to 2 decimal places
# Out:
# 2633.99

# %%
def sg_ott_apr_mean(a):      # Defining custom function sg_ott_apr_mean that can be used to get the mean of the two columns for each golfer and add it as another column
    ott_app_m = a[['SG:OTT','SG:APR']].mean()
    return round(ott_app_m,2)

pga.apply(sg_ott_apr_mean, axis = 1).dropna() # Calling the sg_ott_apr_mean function on the pga dataset
# Out:
# 0     -0.16
# 1      0.25
# 2      0.23
# 3      0.18
# 4     -0.09
#        ...
# 190    0.21
# 191   -0.06
# 192   -0.14
# 193    0.20
# 194   -0.17
# Length: 194, dtype: float64

# %%
avg_driving_distance = pga[['Player', 'AVG_Driving_DISTANCE', 'SG:APR', 'SG:OTT']].dropna() # Creating avg_driving_distance DataFrame

avg_driving_distance['MEAN_SG_APR_OTT'] = avg_driving_distance.apply(sg_ott_apr_mean, axis=1) # Calling the sg_ott_apr_mean function to add the MEAN_SG_APR_OTT column to avg_driving_distance 

top_50_driving_distance = avg_driving_distance.sort_values('AVG_Driving_DISTANCE', ascending = False).head(50) # Create top_50_driving_distance DataFrame of top 50 golfers in AVG_Driving_DISTANCE with longest AVG_Driving_DISTANCE on top
top_50_driving_distance
# Out:
#                   Player  AVG_Driving_DISTANCE  SG:APR  SG:OTT  \
# 149         Rory McIlroy                 320.2   0.195   0.655
# 180        Trey Mullinax                 318.7  -0.416   0.510
# 179           Tony Finau                 316.3   0.490   0.509
# 177         Tom Lovelady                 315.9  -0.240   0.379
# 112            Luke List                 315.2   0.260   0.824
# 60        Dustin Johnson                 314.5   0.824   1.006
# 33          Bubba Watson                 313.6   0.092   0.861
# 31         Brooks Koepka                 313.4   0.228   0.767
# 65         Gary Woodland                 313.2   0.530   0.862
# 99        Keith Mitchell                 312.9  -0.118   0.742
# 97         Justin Thomas                 312.9   0.967   0.471
# 24        Brendan Steele                 311.4   0.306   0.684
# 82             Jason Day                 310.7  -0.133   0.229
# 91              Jon Rahm                 310.5   0.150   0.872
# ...

# %%
bottom_50_driving_distance = avg_driving_distance.sort_values('AVG_Driving_DISTANCE', ascending = False).tail(50) # Create top_50_driving_distance DataFrame of bottom 50 golfers in AVG_Driving_DISTANCE by ordering in descending manner and selecting bottom 50
bottom_50_driving_distance # Show bottom_50_driving_distance DataFrame
# Out:
#                  Player  AVG_Driving_DISTANCE  SG:APR  SG:OTT  MEAN_SG_APR_OTT
# 102        Kevin Kisner                 291.1  -0.306  -0.005            -0.16
# 71       Henrik Stenson                 291.0   0.975   0.587             0.78
# 136       Peter Malnati                 290.9  -0.257  -0.372            -0.31
# 167          Si Woo Kim                 290.6  -0.146  -0.021            -0.08
# 143        Ricky Barnes                 290.6   0.059  -1.019            -0.48
# 10           Andrew Yun                 290.6  -0.447  -0.457            -0.45
# 54            Danny Lee                 290.6  -0.155   0.005            -0.08
# 103            Kevin Na                 290.3   0.373  -0.341             0.02
# 183  Tyrone Van Aswegen                 290.3  -0.008  -0.493            -0.25
# 16        Ben Silverman                 290.2  -0.385   0.069            -0.16
# 46           Chris Kirk                 290.2   0.529  -0.041             0.24
# ...

# %%
round(top_50_driving_distance['MEAN_SG_APR_OTT'].mean(), 2)
# Aim is to see if the top 50 golfers in driving distance had better a better score for the mean of SG:OTT (Strokes Gained Off The Tee) and SG:APR (Strokes Gained Approach) when compared to the bottom 50 golfers in driving distance
# Out:
# 0.26

# %%
round(bottom_50_driving_distance['MEAN_SG_APR_OTT'].mean(), 2)
# When looking at the mean of SG:OTT (Strokes gained off the tee) and SG:APR (Strokes Gained Approach), it's clear that driving distance helps as the top 50 golfers in average driving distance have a much better score for MEAN_SG_APR_OTT (mean of SG:OTT and SG:APR) than the bottom 50 golfers in average driving distance.
# Out:
# -0.17

# %%
for index, row in bottom_50_driving_distance.head(5).iterrows():
    print(index)
    print(row)
# Out:
# 102
# Player                  Kevin Kisner
# AVG_Driving_DISTANCE           291.1
# SG:APR                        -0.306
# SG:OTT                        -0.005
# MEAN_SG_APR_OTT                -0.16
# Name: 102, dtype: object
# 71
# Player                  Henrik Stenson
# AVG_Driving_DISTANCE             291.0
# SG:APR                           0.975
# SG:OTT                           0.587
# MEAN_SG_APR_OTT                   0.78
# Name: 71, dtype: object
# 136
# Player                  Peter Malnati
# AVG_Driving_DISTANCE            290.9
# SG:APR                         -0.257
# SG:OTT                         -0.372
# MEAN_SG_APR_OTT                 -0.31
# Name: 136, dtype: object
# 167
# Player                  Si Woo Kim
# AVG_Driving_DISTANCE         290.6
# SG:APR                      -0.146
# SG:OTT                      -0.021
# MEAN_SG_APR_OTT              -0.08
# Name: 167, dtype: object
# 143
# Player                  Ricky Barnes
# AVG_Driving_DISTANCE           290.6
# ...

# %%
for index, row in top_50_driving_distance.iterrows():
    print(row["Player"], row["MEAN_SG_APR_OTT"])
# Iterate over each row in top_50_driving_distance DataFrame and print the Player and MEAN_SG_APR_OTT columns
# Out:
# Rory McIlroy 0.43
# Trey Mullinax 0.05
# Tony Finau 0.5
# Tom Lovelady 0.07
# Luke List 0.54
# Dustin Johnson 0.92
# Bubba Watson 0.48
# Brooks Koepka 0.5
# Gary Woodland 0.7
# Keith Mitchell 0.31
# Justin Thomas 0.72
# Brendan Steele 0.5
# Jason Day 0.05
# Jon Rahm 0.51
# Kevin Tway 0.15
# Jason Kokrak 0.31
# Kevin Chappell 0.51
# Byeong Hun An 0.49
# Harold Varner III 0.08
# Robert Garrigus 0.27
# Tommy Fleetwood 0.46
# Nick Watney 0.16
# Grayson Murray 0.01
# J.B. Holmes 0.36
# Ryan Palmer 0.25
# Adam Schenk -0.09
# Adam Scott 0.54
# Xander Schauffele 0.21
# Matt Jones 0.01
# Paul Casey 0.44
# Tiger Woods 0.47
# Patrick Rodgers -0.22
# Aaron Wise 0.25
# Corey Conners 0.39
# Jamie Lovemark -0.07
# Patrick Cantlay 0.64
# Jhonattan Vegas 0.12
# Justin Rose 0.5
# Brandon Harkins 0.09
# Hudson Swafford -0.01
# Bronson Burgoon 0.34
# Sam Saunders 0.13
# Sean OHair 0.07
# Seamus Power -0.16
# Hideki Matsuyama 0.33
# Lanto Griffin -0.04
# Harris English -0.26
# Ollie Schniederjans -0.15
# ...

# %%
pga_top_10s = pga[['Player', 'NUMBER_OF_TOP_Tens']] # Create DataFrame

pga_top_10s['Over_2_Top_10s'] = pga_top_10s['NUMBER_OF_TOP_Tens'].apply(lambda x: 'Yes' if x > 2.0 else 'No') # Conditional statement adding Over_2_Top_10s column. Value will be Yes if golfer has more than 2 top 10s or No if golfer has 2 or less top 10s. 
print(pga_top_10s[['Player', 'NUMBER_OF_TOP_Tens', 'Over_2_Top_10s']]) # Print result
# Out:
#                 Player  NUMBER_OF_TOP_Tens Over_2_Top_10s
# 0       Aaron Baddeley                 1.0             No
# 1           Aaron Wise                 4.0            Yes
# 2        Abraham Ancer                 5.0            Yes
# 3          Adam Hadwin                 3.0            Yes
# 4          Adam Schenk                 1.0             No
# ..                 ...                 ...            ...
# 190  Xander Schauffele                 5.0            Yes
# 191       Xinjun Zhang                 1.0             No
# 192          Zac Blair                 0.0             No
# 193       Zach Johnson                 2.0             No
# 194        Zecheng Dou                 0.0             No
#
# [194 rows x 3 columns]
# /var/folders/7j/f055210n60g_b0h6m_7vkpx00000gn/T/ipykernel_6685/4177722703.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
print(pga_top_10s[['Player', 'Over_2_Top_10s']].groupby('Over_2_Top_10s').agg(list)) # Group by Over_2_Top_10s column. Shows the players with Yes or No as their value
# Out:
#                                                            Player
# Over_2_Top_10s
# No              [Aaron Baddeley, Adam Schenk, Alex Cejka, Andr...
# Yes             [Aaron Wise, Abraham Ancer, Adam Hadwin, Adam ...

# %%
sns.scatterplot(x='AGE',y='AVG_Driving_DISTANCE', data=pga, hue='AVG_SMASH_FACTOR', size='NUMBER_OF_WINS') # Scatterplot showing that AVG_Driving_DISTANCE, AVG_SMASH_FACTOR and NUMBER_OF_WINS go down after about the age of 35
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='AVG_Driving_DISTANCE'>

# %%
sns.lineplot(data=pga, x='SG:OTT', y='NUMBER_OF_TOP_Tens') # Line graph showing that better Strokes gained off the tee leads to more top 10s
# Out:
# <AxesSubplot:xlabel='SG:OTT', ylabel='NUMBER_OF_TOP_Tens'>

# %%
pga.plot.scatter('AVG_CLUB_HEAD_SPEED', 'AVG_Driving_DISTANCE', s=2) # Using Panda to plot relationship between AVG_CLUB_HEAD_SPEED (mph) and AVG_Driving_DISTANCE (yards)
# Out:
# <AxesSubplot:xlabel='AVG_CLUB_HEAD_SPEED', ylabel='AVG_Driving_DISTANCE'>
