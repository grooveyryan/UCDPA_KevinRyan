# %%
import pandas as pd # Importing Pandas and calling it pd

import numpy as np

pga = pd.read_csv(r'/Users/kevryan/desktop/PGATOUR_data2.csv') # Importing data set and assigning it variable name 'pga'

pd.DataFrame(pga) # Printing the dataset
# Out:
#              Player  EVENTS_PLAYED  POINTS  NUMBER_OF_WINS  \
# 0    Aaron Baddeley           27.0   342.0             0.0
# 1        Aaron Wise           27.0  1498.0             1.0
# 2     Abraham Ancer           29.0   909.0             0.0
# 3       Adam Hadwin           24.0  1054.0             0.0
# 4       Adam Schenk           28.0   239.0             0.0
# ..              ...            ...     ...             ...
# 326             NaN            NaN     NaN             NaN
# 327             NaN            NaN     NaN             NaN
# 328             NaN            NaN     NaN             NaN
# 329             NaN            NaN     NaN             NaN
# 330             NaN            NaN     NaN             NaN
#
#      NUMBER_OF_TOP_Tens  POINTS_BEHIND_LEAD  ROUNDS_PLAYED  \
# 0                   1.0              5275.0           84.0
# 1                   4.0              4119.0           82.0
# 2                   5.0              4708.0           94.0
# ...

# %%
list(pga) # Listing all fields in pga
# Out:
# ['Player',
#  'EVENTS_PLAYED',
#  'POINTS',
#  'NUMBER_OF_WINS',
#  'NUMBER_OF_TOP_Tens',
#  'POINTS_BEHIND_LEAD',
#  'ROUNDS_PLAYED',
#  'SG_PUTTING_PER_ROUND',
#  'TOTAL_SG:PUTTING',
#  'MEASURED_ROUNDS',
#  'AVG_Driving_DISTANCE',
#  'UP_AND_DOWN_%',
#  'PAR_OR_BETTER',
#  'MISSED_GIR',
#  'FAIRWAY_HIT_%',
#  'FAIRWAYS_HIT',
#  'POSSIBLE_FAIRWAYS',
#  'GIR_RANK',
#  'GOING_FOR_GREEN_IN_2%',
#  'ATTEMPTS_GFG',
#  'NON-ATTEMPTS_GFG',
#  'RTP-GOING_FOR_THE_GREEN',
#  'RTP-NOT_GOING_FOR_THE_GRN',
#  'HOLE_OUTS',
#  'SAND_SAVE%',
#  'NUMBER_OF_SAVES',
#  'NUMBER_OF_BUNKERS',
#  'TOTAL_O/U_PAR',
#  'Three_PUTT%',
#  'TOTAL_3_PUTTS',
#  'SG_PER_ROUND',
#  'SG:OTT',
#  'SG:APR',
#  'SG:ARG',
#  'DRIVES_320+%',
#  'TOTAL_DRIVES_FOR_320+',
#  'TOTAL_DRIVES',
#  'ROUGH_TENDNECY%',
#  'TOTAL_ROUGH',
#  'FAIRWAY_BUNKER%',
#  'TOTAL_FAIRWAY_BUNKERS',
#  'AVG_CLUB_HEAD_SPEED',
#  'FASTEST_CH_SPEED',
#  'SLOWEST_CH_SPEED',
#  'AVG_BALL_SPEED',
#  'FASTEST_BALL_SPEED',
#  'SLOWEST_BALL_SPEED',
# ...

# %%
pga_lowest_spin = pga.sort_values("LOWEST_SPIN_RATE") # Creating pga__lowest_spin DataFrame that has pga DataFrame.

print(pga.columns.get_loc("LOWEST_SPIN_RATE")) # Getting index of LOWEST_SPIN_RATE column
# Out:
# 55

# %%
display(pga_lowest_spin) # Display pga_lowest_spin DataFrame
# Out:
#                Player  EVENTS_PLAYED  POINTS  NUMBER_OF_WINS  \
# 71     Henrik Stenson           15.0   881.0             0.0
# 97      Justin Thomas           21.0  3084.0             3.0
# 156       Ryan Palmer           21.0   900.0             0.0
# 113  Mackenzie Hughes           28.0   227.0             0.0
# 50      Corey Conners           28.0   353.0             0.0
# ..                ...            ...     ...             ...
# 326               NaN            NaN     NaN             NaN
# 327               NaN            NaN     NaN             NaN
# 328               NaN            NaN     NaN             NaN
# 329               NaN            NaN     NaN             NaN
# 330               NaN            NaN     NaN             NaN
#
#      NUMBER_OF_TOP_Tens  POINTS_BEHIND_LEAD  ROUNDS_PLAYED  \
# 71                  5.0              4736.0           56.0
# 97                  9.0              2533.0           83.0
# ...

# %%
top_50_lowest_spin = pga_lowest_spin.head(50) # Creating top_50_lowest_spin DataFrame from the top 50 rows in pga_lowest_spin
display(top_50_lowest_spin) # Displaying top_50_lowest_spin DataFrame
# Out:
#                 Player  EVENTS_PLAYED  POINTS  NUMBER_OF_WINS  \
# 71      Henrik Stenson           15.0   881.0             0.0
# 97       Justin Thomas           21.0  3084.0             3.0
# 156        Ryan Palmer           21.0   900.0             0.0
# 113   Mackenzie Hughes           28.0   227.0             0.0
# 50       Corey Conners           28.0   353.0             0.0
# 145    Robert Garrigus           27.0   353.0             0.0
# 187       Wesley Bryan           23.0   219.0             0.0
# 161       Scott Piercy           25.0   833.0             1.0
# 193       Zach Johnson           24.0   890.0             0.0
# 125  Nicholas Lindheim           26.0   272.0             0.0
# 179         Tony Finau           26.0  3169.0             0.0
# 147       Roberto Diaz           25.0   107.0             0.0
# 135         Paul Casey           18.0  1499.0             1.0
# 37       Cameron Percy           16.0   191.0             0.0
# ...

# %%
top_50_lowest_spin[['Player','LOWEST_SPIN_RATE']] # Accessing only the Player and LOWEST_SPIN_RATE columns
# Out:
#                 Player  LOWEST_SPIN_RATE
# 71      Henrik Stenson            1400.0
# 97       Justin Thomas            1402.0
# 156        Ryan Palmer            1411.0
# 113   Mackenzie Hughes            1418.0
# 50       Corey Conners            1425.0
# 145    Robert Garrigus            1425.0
# 187       Wesley Bryan            1427.0
# 161       Scott Piercy            1431.0
# 193       Zach Johnson            1431.0
# 125  Nicholas Lindheim            1433.0
# 179         Tony Finau            1438.0
# 147       Roberto Diaz            1441.0
# 135         Paul Casey            1442.0
# 37       Cameron Percy            1443.0
# 38       Cameron Smith            1444.0
# 54           Danny Lee            1444.0
# 185      Vaughn Taylor            1447.0
# 14           Ben Crane            1455.0
# 8        Andrew Landry            1456.0
# 9        Andrew Putnam            1461.0
# 62         Ethan Tracy            1470.0
# 66     Graeme McDowell            1476.0
# ...
