# %%
import pandas as pd # Importing Pandas and calling it pd

    pga = pd.read_csv(r'/Users/kevryan/desktop/PGATOUR_data2.csv') # Importing data set and assigning it variable name 'pga'

    pd.DataFrame(pga) # Printing the dataset
# Out:
#              Player  EVENTS_PLAYED  POINTS  NUMBER_OF_WINS  \
# 0    Aaron Baddeley           27.0   342.0             0.0
# 1        Aaron Wise           27.0  1498.0             1.0
# 2     Abraham Ancer           29.0   909.0             0.0
# 3       Adam Hadwin           24.0  1054.0             0.0
# 4       Adam Schenk           28.0   239.0             0.0
# ..              ...            ...     ...             ...
# 326             NaN            NaN     NaN             NaN
# 327             NaN            NaN     NaN             NaN
# 328             NaN            NaN     NaN             NaN
# 329             NaN            NaN     NaN             NaN
# 330             NaN            NaN     NaN             NaN
#
#      NUMBER_OF_TOP_Tens  POINTS_BEHIND_LEAD  ROUNDS_PLAYED  \
# 0                   1.0              5275.0           84.0
# 1                   4.0              4119.0           82.0
# 2                   5.0              4708.0           94.0
# ...

# %%
! pip install -U pandasql # Error message said pandasql module not available. Ran this command in terminal and here to
 #install it

# %%
from pandasql import sqldf # Import Panda SQL for Python to allow writing of SQL queries.

# %%
sqldf("""
    SELECT 
        LONGEST_CARRY_DISTANCE
    FROM pga
    WHERE 
        LONGEST_CARRY_DISTANCE > 305.0
    
""") # Using SQL to list everyone with a longest carry of over 305 yards. 93 golfers satisfied this condition
# Out:
#     LONGEST_CARRY_DISTANCE
# 0                    312.6
# 1                    314.6
# 2                    305.8
# 3                    307.7
# 4                    313.6
# ..                     ...
# 88                   330.4
# 89                   334.4
# 90                   329.6
# 91                   319.5
# 92                   307.2
#
# [93 rows x 1 columns]
